# %%
import pandas as pd

# %%
# Reading in billionaires csv to be cleaned
billionaires_df = pd.read_csv('Resources/forbes_billionaires.csv')

# %%
# showing what the billionaires csv looks like as a df
billionaires_df
# Out:
#                           Name  NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos     177.0  United States         Amazon     1
# 1                    Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family     150.0         France           LVMH     3
# 3                   Bill Gates     124.0  United States      Microsoft     4
# 4              Mark Zuckerberg      97.0  United States       Facebook     5
# ...                        ...       ...            ...            ...   ...
# 2750         Daniel Yong Zhang       1.0          China     e-commerce  2674
# 2751             Zhang Yuqiang       1.0          China     Fiberglass  2674
# 2752             Zhao Meiguang       1.0          China    gold mining  2674
# 2753            Zhong Naixiong       1.0          China   conglomerate  2674
# 2754           Zhou Wei family       1.0          China       Software  2674
#
# ...

# %%
#dropping columns we dont want
cleaned_billionaires_df = billionaires_df.drop (['Rank','Residence','Citizenship','Status','Children','Self_made','geometry'], axis=1)

# %%
#adding 0's to missing ages
cleaned_billionaires_df['Age'].loc[cleaned_billionaires_df['Age'].notnull()]
# Out:
# 0       57.0
# 1       49.0
# 2       72.0
# 3       65.0
# 4       36.0
#         ...
# 2750    49.0
# 2751    65.0
# 2752    58.0
# 2753    58.0
# 2754    54.0
# Name: Age, Length: 2630, dtype: float64

# %%
cleaned_billionaires_df.to_csv('Resources/cleaned_data/cleaned_billionaires.csv',index=False)
